# %%
import PyPDF2 
import textract
#from nltk.tokenize import word_tokenize
#from nltk.corpus import stopwords
import requests 
import re
import pandas as pd

# %%
#Download the pdf file
file_url = "http://ceo.karnataka.gov.in/finalrolls_2020/English/MR/AC163/S10A163P1.pdf"
  
r = requests.get(file_url, stream = True) 
  
with open("list_of_electorals.pdf","wb") as pdf: 
    for chunk in r.iter_content(chunk_size=1024): 
  
         # writing one chunk at a time to pdf file 
         if chunk: 
             pdf.write(chunk)

# %%
#Write a for-loop to open many files (leave a comment if you'd like to learn how).
filename = 'list_of_electorals.pdf' 
#open allows you to read the file.
pdfFileObj = open(filename,'rb')
#The pdfReader variable is a readable object that will be parsed.
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
#Discerning the number of pages will allow us to parse through all the pages.
num_pages = pdfReader.numPages
count = 0
text = ""
#The while loop will read each page.
while count < num_pages:
    pageObj = pdfReader.getPage(count)
    count +=1
    text += pageObj.extractText()
#This if statement exists to check if the above library returned words. It's done because PyPDF2 cannot read scanned files.
if text != "":
    #print("XYZ  ABC")
    text = text
#If the above returns as False, we run the OCR library textract to #convert scanned/image based PDF files into text.
else:
    text = textract.process(filename, method='tesseract', language='eng')
#Now we have a text variable that contains all the text derived from our PDF file. Type print(text) to see what it contains. It likely contains a lot of spaces, possibly junk such as '\n,' etc.
#Now, we will clean our text variable and return it as a list of keywords.

# %%
print(count, num_pages)
# Out:
# 44 44

# %%
print(text)
# Out:
# b'ELECTORAL ROLL 2020 $10 Karnataka\n\n \n\n \n\nNo. Name and Reservation Status of Assembly Constituency : 163 - Part number\n\nShantinagar (GEN)\n\n1\n\n \n\n \n\nNo. Name and Reservation Status of Parliamentary Constituency(ies) in which the Assembly\n\nConstituency is located : 25 - Bangalore Central\n\n(GEN)\n\n \n\n1. Details of Revision\n\n \n\nYear of Revision 2020\n\nQualifying Date 01-01-2020\n\nSpecial Summary Revision\n\nType of revision 2020\n\nDate of Publication 07-02-2020\n\nRoll Identification\nBasic (Mother) Roll of 2020\n\n \n\n2. Details of part and polling area\n\n \n\nNo. and name of sections in the part\n\n \n\nLavelle Road Main Town / City\n\n: Bangalore\n\n   \n \n\n \n\n \n\n1.\n2. Lavelle Road 1st Cross\n3. Lavelle Road, 3rd Cross Ward No 11-Shantala Nagar\n4. Lavelle Road 7th Cross District .B.M.P(CENTRAL)\n5. Kasthurba Road Post Office\n6. Raja Ram Mohan Ray Road Pin Code :\n7. Vittal Mallya Road (Partly) Police Station 2 Cubbon Park\n8. Waltan Road\n999.
# ...

# %%
type(text)
# Out:
# bytes

# %%
text1=str(text)

# %%
print(text1)
# Out:
# b'ELECTORAL ROLL 2020 $10 Karnataka\n\n \n\n \n\nNo. Name and Reservation Status of Assembly Constituency : 163 - Part number\n\nShantinagar (GEN)\n\n1\n\n \n\n \n\nNo. Name and Reservation Status of Parliamentary Constituency(ies) in which the Assembly\n\nConstituency is located : 25 - Bangalore Central\n\n(GEN)\n\n \n\n1. Details of Revision\n\n \n\nYear of Revision 2020\n\nQualifying Date 01-01-2020\n\nSpecial Summary Revision\n\nType of revision 2020\n\nDate of Publication 07-02-2020\n\nRoll Identification\nBasic (Mother) Roll of 2020\n\n \n\n2. Details of part and polling area\n\n \n\nNo. and name of sections in the part\n\n \n\nLavelle Road Main Town / City\n\n: Bangalore\n\n   \n \n\n \n\n \n\n1.\n2. Lavelle Road 1st Cross\n3. Lavelle Road, 3rd Cross Ward No 11-Shantala Nagar\n4. Lavelle Road 7th Cross District .B.M.P(CENTRAL)\n5. Kasthurba Road Post Office\n6. Raja Ram Mohan Ray Road Pin Code :\n7. Vittal Mallya Road (Partly) Police Station 2 Cubbon Park\n8. Waltan Road\n999.
# ...

# %%
New_text = text1.replace(r'\n', " ")

# %%
#Removing multiple space
New_text = re.sub(r"\s+"," ", New_text)

# %%
New_text
# Out:
# 'b\'ELECTORAL ROLL 2020 $10 Karnataka No. Name and Reservation Status of Assembly Constituency : 163 - Part number Shantinagar (GEN) 1 No. Name and Reservation Status of Parliamentary Constituency(ies) in which the Assembly Constituency is located : 25 - Bangalore Central (GEN) 1. Details of Revision Year of Revision 2020 Qualifying Date 01-01-2020 Special Summary Revision Type of revision 2020 Date of Publication 07-02-2020 Roll Identification Basic (Mother) Roll of 2020 2. Details of part and polling area No. and name of sections in the part Lavelle Road Main Town / City : Bangalore 1. 2. Lavelle Road 1st Cross 3. Lavelle Road, 3rd Cross Ward No 11-Shantala Nagar 4. Lavelle Road 7th Cross District .B.M.P(CENTRAL) 5. Kasthurba Road Post Office 6. Raja Ram Mohan Ray Road Pin Code : 7. Vittal Mallya Road (Partly) Police Station 2 Cubbon Park 8. Waltan Road 999. NRINRI 3. Polling Station Details Type of Polling Station GENERAL No. and Name of Polling Station : 1-St Joseph Indian School
# ...

# %%
#New_text = text1.replace(r"Name :", "Name:")

# %%
l = New_text.split()

# %%
len(l)
# Out:
# 25223

# %%
print(l)
# Out:
# ["b'ELECTORAL", 'ROLL', '2020', '$10', 'Karnataka', 'No.', 'Name', 'and', 'Reservation', 'Status', 'of', 'Assembly', 'Constituency', ':', '163', '-', 'Part', 'number', 'Shantinagar', '(GEN)', '1', 'No.', 'Name', 'and', 'Reservation', 'Status', 'of', 'Parliamentary', 'Constituency(ies)', 'in', 'which', 'the', 'Assembly', 'Constituency', 'is', 'located', ':', '25', '-', 'Bangalore', 'Central', '(GEN)', '1.', 'Details', 'of', 'Revision', 'Year', 'of', 'Revision', '2020', 'Qualifying', 'Date', '01-01-2020', 'Special', 'Summary', 'Revision', 'Type', 'of', 'revision', '2020', 'Date', 'of', 'Publication', '07-02-2020', 'Roll', 'Identification', 'Basic', '(Mother)', 'Roll', 'of', '2020', '2.', 'Details', 'of', 'part', 'and', 'polling', 'area', 'No.', 'and', 'name', 'of', 'sections', 'in', 'the', 'part', 'Lavelle', 'Road', 'Main', 'Town', '/', 'City', ':', 'Bangalore', '1.', '2.', 'Lavelle', 'Road', '1st', 'Cross', '3.', 'Lavelle', 'Road,', '3rd', 'Cross', 'Ward', 'No', '11-Shantala', 'Nagar'
# ...

# %%
f_name = []
m_name = []
l_name = []

# %%
for i in range(len(l)):
    if l[i] == 'Name.' and (l[i+2] == 'Name:' or l[i+2]=='Name' or l[i+2] == "Name."):
        print('Name have 1 word:::')
        #print(l[i+1])
        f_name.append(l[i+1])
        m_name.append("")
        l_name.append("")
    elif l[i] == 'Name.' and (l[i+3] == 'Name:' or l[i+3]=='Name' or l[i+3] == "Name."):
        print('Name have 1 word:::')
        #print(l[i+1])
        f_name.append(l[i+1])
        m_name.append("")
        l_name.append("")
    elif l[i] == 'Name.' and (l[i+4] == 'Name:' or l[i+4]=='Name' or l[i+4] == "Name."):
        print('Name have 1 word:::')
        #print(l[i+1])
        f_name.append(l[i+1])
        m_name.append("")
        l_name.append("")
    
 #####################################################################   
    elif l[i] == 'Name:' and (l[i+2] == 'Name:' or l[i+2]=='Name'):
        print('Name have 1 word:::')
        #print(l[i+1])
        f_name.append(l[i+1])
        m_name.append("")
        l_name.append("")
        #print(l[i+2])
    elif l[i] == 'Name:' and (l[i+2] == "Husband\\'s" or l[i+2] == "Father\\'s"):
        print('Name have 1 word:::')
        #print(l[i+1])
        f_name.append(l[i+1])
        m_name.append("")
        l_name.append("")
        #print(l[i+2])
    elif l[i] == 'Name' and l[i+1] != ':' and (l[i+2] == "Father\\'s" or l[i+2] == "Husband\\'s"):
        print('Name have 1 word:::')
        #print(l[i+1])
        f_name.append(l[i+1])
        m_name.append("")
        l_name.append("")
        #print(l[i+2])
    elif l[i] == 'Name:' and l[i+3] == 'Name:':
        print('Name have 2 word:::')
        #print(l[i+1])
        #print(l[i+2])
        f_name.append(l[i+1])
        m_name.append("")
        l_name.append(l[i+2])
    elif l[i] == 'Name:' and l[i+4] == 'Name:':
        print('Name have 3 word:::')
        #print(l[i+1])
        #print(l[i+2])
        #print(l[i+3])
        f_name.append(l[i+1])
        m_name.append(l[i+2])
        l_name.append(l[i+3])
    elif l[i] == 'Name:' and l[i+3] == "Husband\\'s":
        print('Name have 2 word and then husband name')
#         print(l[i+1])
#         print(l[i+2])
        f_name.append(l[i+1])
        m_name.append("")
        l_name.append(l[i+2])
    elif l[i] == 'Name:' and l[i+4] == "Husband\\'s":
        print('Name have 3 word and then husband name')
#         print(l[i+1])
#         print(l[i+2])
#         print(l[i+3])
        f_name.append(l[i+1])
        m_name.append(l[i+2])
        l_name.append(l[i+3])
    elif l[i] == 'Name:' and l[i+3] == "Father\\'s":
        print('Name have 2 word and then father name')
#         print(l[i+1])
#         print(l[i+2])
        f_name.append(l[i+1])
        m_name.append("")
        l_name.append(l[i+2])
                    
    elif l[i] == 'Name:' and l[i+4] == "Father\\'s":
        print('Name have 3 word and then father name')
#         print(l[i+1])
#         print(l[i+2])
#         print(l[i+3])
        f_name.append(l[i+1])
        m_name.append(l[i+2])
        l_name.append(l[i+3])
    elif l[i] == 'Name:' and l[i+3] == 'Name':
        print('Name have 2 word:::')
#         print(l[i+1])
#         print(l[i+2])
        f_name.append(l[i+1])
        m_name.append("")
        l_name.append(l[i+2])
    elif l[i] == 'Name:' and l[i+4] == 'Name':
        print('Name have 3 word:::')
#         print(l[i+1])
#         print(l[i+2])
#         print(l[i+3])
        f_name.append(l[i+1])
        m_name.append(l[i+2])
        l_name.append(l[i+3])
    elif l[i] == 'Name' and l[i+1] != ':' and (l[i+3] == "Father\\'s" or l[i+3] == "Husband\\'s"):
        print('Name have 2 word:::')
#         print(l[i+1])
#         print(l[i+2])
        f_name.append(l[i+1])
        m_name.append("")
        l_name.append(l[i+2])
    elif l[i] == 'Name' and l[i+1] != ':' and (l[i+4] == "Father\\'s" or l[i+4] == "Husband\\'s"):
        print('Name have 3 word:::')
#         print(l[i+1])
#         print(l[i+2])
#         print(l[i+3])
        f_name.append(l[i+1])
        m_name.append(l[i+2])
        l_name.append(l[i+3])
# Out:
# Name have 3 word:::
# Name have 3 word:::
# Name have 3 word and then husband name
# Name have 2 word:::
# Name have 3 word:::
# Name have 2 word:::
# Name have 2 word:::
# Name have 2 word:::
# Name have 2 word and then husband name
# Name have 2 word:::
# Name have 2 word:::
# Name have 1 word:::
# Name have 2 word:::
# Name have 2 word:::
# Name have 1 word:::
# Name have 1 word:::
# Name have 3 word:::
# Name have 1 word:::
# Name have 1 word:::
# Name have 3 word:::
# Name have 1 word:::
# Name have 1 word:::
# Name have 1 word:::
# Name have 3 word:::
# Name have 1 word:::
# Name have 1 word:::
# Name have 1 word:::
# Name have 1 word:::
# Name have 2 word and then husband name
# Name have 2 word:::
# Name have 2 word and then husband name
# Name have 2 word:::
# Name have 2 word and then husband name
# Name have 2 word:::
# Name have 2 word:::
# Name have 3 word:::
# Name have 2 word and then husband name
# Name have 2 word:::
# Name have 3 word:::
# Name have 2 word:::
# ...

# %%
print(len(f_name))
print(len(m_name))
print(len(l_name))
# Out:
# 1019
# 1019
# 1019

# %%
name_list = pd.DataFrame(columns = ['Fisrt Name', 'Middle Name', 'Last Name'])

# %%
name_list["Fisrt Name"] = f_name
name_list["Middle Name"] = m_name
name_list["Last Name"] = l_name

# %%
name_list
# Out:
#          Fisrt Name Middle Name         Last Name
# 0             Meera       Mohan          Bharvani
# 1           Brijaya           N             Kalro
# 2                CG        arun             Kumar
# 3             Henna                         Kalro
# 4              Yash           B             Kalro
# 5            Indira                       Shambhu
# 6            Nalini                        Ramesh
# 7           Lakshmi                        Mukund
# 8                 A                 Arockianathan
# 9          Lawrance                     Rodrigues
# 10             C.A.                        Joseph
# 11         Yandayya
# 12           Aditya                        Sondhi
# 13           Aditya                      Mendonca
# 14    H\'S.SRINIVAS
# 15       VENKATAMMA
# 16             Siji          K.            Thomas
# 17       SHIVARAM.R
# 18           Thomas
# 19         RAMESH.R       Name.       NAGESHEWARI
# 20      NAGESHEWARI
# 21          Mythrai
# ...

# %%
name_list.to_csv('NameList.csv')
